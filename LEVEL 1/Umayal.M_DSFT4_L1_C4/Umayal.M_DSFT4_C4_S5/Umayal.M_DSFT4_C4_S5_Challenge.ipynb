# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Umayal.M_DSFT4_C4\\Umayal.M_DSFT4_C4_S5'

# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\Admin\\car_prices.csv')
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
# TASK 1
# low price car manufactured in 2014
   # manfacturer of 5 low priced car

# %%
a=df[df.year==2014]
#a

# %%
c=(a.groupby(by='make')['sellingprice'].mean()).sort_values()
print('low price car manufactured in 2014 are \n')
print(c.head())
# Out:
# low price car manufactured in 2014 are
#
# make
# smart          8620.000000
# FIAT          12585.109290
# Mitsubishi    13502.323838
# Kia           14341.490037
# Volkswagen    14840.196850
# Name: sellingprice, dtype: float64

# %%
# TASK 2
#BMW selling price in 2010 and 2015(diff)
  #condition>4.5, avg selling price in terms of percent(diff)

# %%
s1=df[df.make=='BMW']
s1
# Out:
#         year make                model        trim         body transmission  \
# 2       2014  BMW             3 Series  328i SULEV        Sedan    automatic
# 4       2014  BMW  6 Series Gran Coupe        650i        Sedan    automatic
# 6       2014  BMW                   M5        Base        Sedan    automatic
# 19      2014  BMW             6 Series        650i  Convertible    automatic
# 21      2014  BMW             5 Series        528i        Sedan    automatic
# ...      ...  ...                  ...         ...          ...          ...
# 558781  2006  BMW             3 Series        330i        Sedan    automatic
# 558783  2003  BMW             3 Series        330i        Sedan    automatic
# 558808  2008  BMW             1 Series        135i  Convertible    automatic
# 558831  2011  BMW             5 Series        528i        Sedan    automatic
# 558834  2012  BMW                   X5   xDrive35d          SUV    automatic
#
# ...

# %%
#2010
y1=s1[s1.year==2010]
y1
# Out:
#         year make     model          trim   body transmission  \
# 2502    2010  BMW  3 Series          328i  Sedan    automatic
# 2519    2010  BMW  7 Series         750Li  Sedan    automatic
# 2529    2010  BMW  3 Series          328i  Sedan    automatic
# 2550    2010  BMW  3 Series          328i  Sedan    automatic
# 2598    2010  BMW  7 Series         750Li  Sedan    automatic
# ...      ...  ...       ...           ...    ...          ...
# 557627  2010  BMW  3 Series   335i xDrive  sedan    automatic
# 557631  2010  BMW        X5     xDrive48i    suv          NaN
# 557635  2010  BMW  7 Series  750Li xDrive  sedan    automatic
# 558051  2010  BMW  3 Series          328i  sedan    automatic
# 558688  2010  BMW  5 Series   528i xDrive  sedan          NaN
#
#                       vin state  condition  odometer   color interior  \
# 2502    wbaph5g54anm35174    ca        3.5   66228.0    gray     gray
# 2519    wbakb8c58acy63859    ca        3.7   64010.0   beige    beige
# ...

# %%
a1=y1[y1.condition>4.5]['sellingprice'].mean()
a1
# Out:
# 23572.222222222223

# %%
#2015
y2=s1[s1.year==2015]
y2
# Out:
#         year make model       trim   body transmission                vin  \
# 7876    2015  BMW    M4       Base  Coupe    automatic  wbs3r9c53fk329392
# 43585   2015  BMW    X1  xDrive28i    SUV    automatic  wbavl1c56fvy26418
# 56898   2015  BMW    X1  xDrive28i    SUV    automatic  wbavl1c56fvy24992
# 56900   2015  BMW    X1  xDrive35i    SUV    automatic  wbavm5c51fvv93813
# 56901   2015  BMW    X1  xDrive28i    SUV    automatic  wbavl1c58fvy29451
# ...      ...  ...   ...        ...    ...          ...                ...
# 552386  2015  BMW    X5  xDrive35i    suv    automatic  5uxkr0c51f0p01630
# 553182  2015  BMW    X5  sDrive35i    suv    automatic  5uxkr2c57f0h37045
# 553663  2015  BMW    X1  sDrive28i    suv    automatic  wbavm1c54fvz93907
# 555500  2015  BMW    X5  xDrive35i    suv    automatic  5uxkr0c53f0k66853
# 557843  2015  BMW    M4       Base  coupe    automatic  wbs3r9c52fk329996
#
#        state  condition  odometer  color interior  \
# ...

# %%
a2=y2[y2.condition>4.5]['sellingprice'].mean()
a2
# Out:
# 42994.68599033816

# %%
#percentage
diff=(a2-a1)/a2*100
print('Percentage by which the avg selling price of BMW cars with good condition having a score more than 4.5 in 2010 is less than',diff,'%','that of 2015')
# Out:
# Percentage by which the avg selling price of BMW cars with good condition having a score more than 4.5 in 2010 is less than 45.17410307980988 % that of 2015

# %%
# TASK 3 
#interior color impacts wholesale price of car
    #diff b/w avg whole sale price(mmr) of cars with interior black & gray

# %%
#black
black=df[df.interior=='black']['mmr'].mean()
black
# Out:
# 15858.52005549485

# %%
#gray
gray=df[df.interior=='gray']['mmr'].mean()
gray
# Out:
# 11189.776545228522

# %%
#diff
print('Difference between average whole sale price of cars with black and gray interior is',black-gray)
# Out:
# Difference between average whole sale price of cars with black and gray interior is 4668.743510266328

# %%
# TASK 4
#color impacts price of the car
  # from 2013 to 2015,colour wise total no.of manufacturer

# %%
#year
year=df[(df.year>=2013)&(df.year<=2015)]
year
# Out:
#         year    make                model        trim       body transmission  \
# 0       2015     Kia              Sorento          LX        SUV    automatic
# 1       2015     Kia              Sorento          LX        SUV    automatic
# 2       2014     BMW             3 Series  328i SULEV      Sedan    automatic
# 3       2015   Volvo                  S60          T5      Sedan    automatic
# 4       2014     BMW  6 Series Gran Coupe        650i      Sedan    automatic
# ...      ...     ...                  ...         ...        ...          ...
# 558826  2014    Jeep       Grand Cherokee     Limited        SUV    automatic
# 558827  2014    Jeep       Grand Cherokee      Laredo        SUV    automatic
# 558832  2015     Kia                 K900      Luxury      Sedan          NaN
# 558835  2015  Nissan               Altima       2.5 S      sedan    automatic
# 558836  2014    Ford                F-150         XLT  SuperCrew    automatic
#
# ...

# %%
g=year.groupby(by='color')['make'].count()
g
# Out:
# color
# beige         1686
# black        35563
# blue         13744
# brown         2672
# burgundy      2486
# charcoal       187
# gold          1744
# gray         29464
# green         2096
# lime             8
# off-white      375
# orange         583
# pink            29
# purple         397
# red          17230
# silver       26143
# turquoise       35
# white        40055
# yellow         262
# —            12801
# Name: make, dtype: int64

# %%
# FOR EACH MANFUCTURE-COUNT
pd.crosstab(year.color,year.make,rownames=['color'],colnames=['make'])
# for all count  pd.crosstab(df.color,df.make,rownames=['color'],colnames=['make'])
# Out:
# make       Acura  Audi   BMW  Bentley  Buick  Cadillac  Chevrolet  Chrysler  \
# color
# beige          0     2    34        0     21        55        421       175
# black        170   402  1235        5    157       298       3570      1599
# blue          19    78   252        3     55        36       1582       848
# brown          5    10    99        0     25        12        153        56
# burgundy      20     1     1        0     12         2        167       232
# charcoal       2     0     1        0      1         0         36        18
# gold           0     1     8        0     19        50        354       334
# gray         107   181   710        3    189        85       2933      1343
# green          1     0     4        0      0         1        160         2
# lime           0     0     0        0      0         0          1         0
# off-white      3     0     2        0     11        11         24         4
# ...

# %%
# TASK 5
   #total sales of cars with SUV bodies on 'Fri Dec 19,2014, 09:00:00 GMT-0800' and 'Thu Jan 15,2015, 04:30:00 GMT-0800 (PST)'
   #sales of car(%) in this period

# %%
#filter
f1=df[(df.body=='SUV')&(df.saledate=='Thu Jan 15 2015 04:30:00 GMT-0800 (PST)')]
#f1

# %%
f2=df[(df.body=='SUV')&(df.saledate=='Fri Dec 19 2014 09:00:00 GMT-0800 (PST)')]
#f2

# %%
#total sales
sale1=f1['sellingprice'].sum()
print('Total sale of cars with SUV bodies during Thu Jan 15 2015=',sale1)
sale2=f2['sellingprice'].sum()
print('Total sale of cars with SUV bodies during Fri Dec 19 2014=',sale2)
# Out:
# Total sale of cars with SUV bodies during Thu Jan 15 2015= 9650725
# Total sale of cars with SUV bodies during Fri Dec 19 2014= 10343000

# %%
#percentage
dif=((sale2-sale1)/sale2)*100
print('The total sales of car with SUV body in Thu Jan 15 2015 04:30:00 GMT-0800 (PST) has decreased by',dif,'%',' while comparing with Fri Dec 19 2014 09:00:00 GMT-0800 (PST)')
# Out:
# The total sales of car with SUV body in Thu Jan 15 2015 04:30:00 GMT-0800 (PST) has decreased by 6.693174127429178 %  while comparing with Fri Dec 19 2014 09:00:00 GMT-0800 (PST)

# %%
# TASK 6
  #ford and chevrolet 10% discount and all others 20%
  #new column 'Discounted_Price' after selling price

# %%
#new column
df['Discounted_Price']=0.2*df['sellingprice']
b=0.1*df['sellingprice']
df.loc[(df.make=='Chevrolet')|(df.make=='Ford'),'Discounted_Price']=b
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
aa=df.pop('Discounted_Price')
df.insert(15,"Discounted_Price",aa)
print('After inserting Discounted_Price column near to sellingprice')
df
# Out:
# After inserting Discounted_Price column near to sellingprice
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# ...

# %%
# TASK 7
  #remove 2 columns
  #fill missing data

# %%
#remove columns
df.pop('vin')
df.pop('saledate')
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission state  condition  odometer   color interior  \
# 0         automatic    ca        5.0   16639.0   white    black
# ...

# %%
print(df.isnull().sum())
print(df.info())
# Out:
# year                    0
# make                10301
# model               10399
# trim                10651
# body                13195
# transmission        65353
# state                   1
# condition           11794
# odometer               94
# color                 749
# interior              749
# seller                  0
# mmr                     0
# sellingprice            0
# Discounted_Price        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   year              558837 non-null  int64
#  1   make              548536 non-null  object
#  2   model             548438 non-null  object
#  3   trim              548186 non-null  object
#  4   body              545642 non-null  object
#  5   transmission      493484 non-null  object
#  6   state             558836 non-null  object
# ...

# %%
#MAKE
#finding missing one
m1=df['make'].value_counts()
m1.sort_values(ascending=False)
# Out:
# Ford          93554
# Chevrolet     60197
# Nissan        53946
# Toyota        39871
# Dodge         30710
#               ...
# airstream         1
# dot               1
# hyundai tk        1
# mazda tk          1
# Lotus             1
# Name: make, Length: 96, dtype: int64

# %%
#filling
df['make']=df['make'].fillna('Ford')

# %%
#MODEL
#finding missing one
df['model'].value_counts()
# Out:
# Altima        19349
# F-150         14479
# Fusion        12946
# Camry         12545
# Escape        11861
#               ...
# siera             1
# avalon            1
# c240s             1
# allure            1
# 458 Italia        1
# Name: model, Length: 973, dtype: int64

# %%
#filling
df['model']=df['model'].fillna('Altima')

# %%
#TRIM
#finding missing one
df['trim'].value_counts()
# Out:
# Base                 55817
# SE                   43648
# LX                   20757
# Limited              18356
# LT                   16915
#                      ...
# 4x2 reg silver ls        1
# 25 4x4 cr sle            1
# xl                       1
# 4x4 v6 xlt sport         1
# Power Wagon              1
# Name: trim, Length: 1972, dtype: int64

# %%
#filling
df['trim']=df['trim'].fillna('Base')

# %%
#BODY
#finding missing one
df['body'].value_counts()
# Out:
# Sedan          199437
# SUV            119292
# sedan           41906
# suv             24552
# Hatchback       21380
#                 ...
# Ram Van             1
# CTS-V Wagon         1
# g37 coupe           1
# cab plus 4          1
# cts wagon           1
# Name: body, Length: 87, dtype: int64

# %%
#filling
df['body']=df['body'].fillna('Sedan')

# %%
#TRANSMISSION
#finding missing one
df['transmission'].value_counts()
# Out:
# automatic    475914
# manual        17544
# sedan            15
# Sedan            11
# Name: transmission, dtype: int64

# %%
#filling
df['transmission']=df['transmission'].fillna('automatic')

# %%
#STATE
#finding missing one
df['state'].value_counts()
# Out:
# fl    82952
# ca    73152
# pa    53909
# tx    45914
# ga    34753
# nj    27784
# il    23486
# nc    21845
# oh    21575
# tn    20895
# mo    16013
# mi    15511
# nv    12685
# va    12029
# md    11158
# wi     9852
# mn     9429
# az     8741
# co     7776
# wa     7416
# ma     6729
# ny     5699
# in     4326
# sc     4252
# ne     4013
# on     3442
# pr     2725
# la     2191
# ms     1853
# ut     1836
# qc     1245
# hi     1237
# or     1155
# ab      928
# nm      171
# ok       72
# ns       61
# al       26
# Name: state, dtype: int64

# %%
#filling
df['state']=df['state'].fillna('fl')

# %%
#CONDITION
#finding missing one
avg=df['condition'].mean()
print(avg)
# Out:
# 3.424510504655353

# %%
#filling
df['condition']=df['condition'].fillna(avg)

# %%
#ODOMETER
#finding missing one
avg1=df['odometer'].mean()
print(avg1)
# Out:
# 68320.43754821089

# %%
#filling
df['odometer']=df['odometer'].fillna(avg1)

# %%
#COLOR
#finding missing one
df['color'].value_counts()
# Out:
# black        110974
# white        106677
# silver        83394
# gray          82860
# blue          51144
# red           43573
# —             24686
# green         11382
# gold          11342
# beige          9222
# burgundy       8972
# brown          6717
# orange         2078
# purple         1561
# off-white      1449
# yellow         1285
# charcoal        479
# turquoise       236
# pink             42
# lime             15
# Name: color, dtype: int64

# %%
#filling
df['color']=df['color'].fillna('black')

# %%
#INTERIOR
#finding missing one
df['interior'].value_counts()
# Out:
# black        244347
# gray         178582
# beige         59758
# tan           44093
# —             17076
# brown          8640
# red            1359
# blue           1138
# silver         1099
# off-white       480
# purple          339
# gold            324
# white           252
# green           245
# burgundy        191
# orange          145
# yellow           20
# Name: interior, dtype: int64

# %%
#filling
df['interior']=df['interior'].fillna('black')

# %%
print(df.isnull().sum())
print(df.info())
# Out:
# year                0
# make                0
# model               0
# trim                0
# body                0
# transmission        0
# state               0
# condition           0
# odometer            0
# color               0
# interior            0
# seller              0
# mmr                 0
# sellingprice        0
# Discounted_Price    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   year              558837 non-null  int64
#  1   make              558837 non-null  object
#  2   model             558837 non-null  object
#  3   trim              558837 non-null  object
#  4   body              558837 non-null  object
#  5   transmission      558837 non-null  object
#  6   state             558837 non-null  object
#  7   condition         558837 non-null  float64
# ...

# %%
# END
