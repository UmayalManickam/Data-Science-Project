# %%
import pandas as pd
df=pd.read_csv('housing.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# TASK 1

# %%
a=df[(df.LotArea>=6000) & (df.LotConfig=='Corner')]
print('THe corner houses that are atleast 6000sq.feet are shown below:')
a
# Out:
# THe corner houses that are atleast 6000sq.feet are shown below:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1407  1408          20       RL          NaN     8780   Pave   NaN      IR1
# 1413  1414          20       RL         88.0    10994   Pave   NaN      IR1
# 1420  1421          60       RL         90.0    11700   Pave   NaN      Reg
# 1428  1429          30       RM         60.0     7200   Pave   NaN      Reg
# ...

# %%
# TASK 2

# %%
b=df[(df.HouseStyle=='1Story') & (df.BldgType=='1Fam') & (df.LandContour=='Lvl')]
print('The houses in flat land for One family with one story style are shown below:')
b
# Out:
# The houses in flat land for One family with one story style are shown below:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# ...

# %%
# TASK 3

# %%
c=df[(df.BldgType=='TwnhsE')]
print('The townhouse building type are shown below:')
c
# Out:
# The townhouse building type are shown below:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# 34      35         120       RL         60.0     7313   Pave   NaN      Reg
# 45      46         120       RL         61.0     7658   Pave   NaN      Reg
# 62      63         120       RL         44.0     6442   Pave   NaN      IR1
# 81      82         120       RM         32.0     4500   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1421  1422         120       RL         53.0     4043   Pave   NaN      Reg
# 1422  1423         120       RM         37.0     4435   Pave   NaN      Reg
# 1431  1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
#
# ...

# %%
avg=c['LotArea'].mean()
print('Average Lot area for townhouse building type =',avg)
# Out:
# Average Lot area for townhouse building type = 4766.605263157895

# %%
# TASK 4

# %%
d=df[(df.Exterior2nd=='CmentBd') & (df.BedroomAbvGr>3) & (df.BsmtQual!='NA')]
print('The houses with more than 3 bedrooms,cement exterior and basement are shown below: ')
d
# Out:
# The houses with more than 3 bedrooms,cement exterior and basement are shown below:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 316    317          60       RL         94.0    13005   Pave   NaN      IR1
# 349    350          60       RL         56.0    20431   Pave   NaN      IR2
# 377    378          60       FV        102.0    11143   Pave   NaN      IR1
# 875    876          60       FV         75.0     9000   Pave   NaN      Reg
# 983    984          60       RL          NaN    11250   Pave   NaN      Reg
# 1046  1047          60       RL         85.0    16056   Pave   NaN      IR1
# 1068  1069         160       RM         42.0     3964   Pave   NaN      Reg
# 1367  1368         160       RM         41.0     2665   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
# TASK 5

# %%
e=df[(df.GarageCars==2) & (df.GarageArea>=500)]
print('Garage with 2 cars and atleast 500 sq ft')
e
# Out:
# Garage with 2 cars and atleast 500 sq ft
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
#
# ...

# %%
#concatenating 5 dataframe into one
DF=[a,b,c,d]
Mergeddf=pd.concat(DF)
print(Mergeddf.shape)
#Mergeddf
# Out:
# (909, 81)

# %%
#connecting mysql and python
# !pip install mysql-connector-python

# %%
import mysql.connector as sql

# %%
db=sql.connect(host='localhost',user='root',password='Umayal_2000',database='abc')
mycursor=db.cursor()

# %%
#PUSHING DATAFRAME TO MYSQL
# !pip install pymysql

# %%
from sqlalchemy import create_engine
hostname='localhost'
dbname='abc'
uname='root'
pwd='Umayal_2000'
engine=create_engine("mysql+pymysql://{user}:{pwd}@{host}/{db}"
                     .format(host='localhost',db='abc',user='root',pwd='Umayal_2000'))

# %%
Mergeddf.to_sql("New_Record",engine,index=False)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'New_Record' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
import mysql.connector as sql
db=sql.connect(host='localhost',user='root',password='Umayal_2000',database='abc')
mycursor=db.cursor()

# %%
mycursor.execute('select * from New_Record')
for l in mycursor:
    print(l)
# Out:
# (4, 70, 'RL', 60.0, 9550, 'Pave', None, 'IR1', 'Lvl', 'AllPub', 'Corner', 'Gtl', 'Crawfor', 'Norm', 'Norm', '1Fam', '2Story', 7, 5, 1915, 1970, 'Gable', 'CompShg', 'Wd Sdng', 'Wd Shng', 'None', 0.0, 'TA', 'TA', 'BrkTil', 'TA', 'Gd', 'No', 'ALQ', 216, 'Unf', 0, 540, 756, 'GasA', 'Gd', 'Y', 'SBrkr', 961, 756, 0, 1717, 1, 0, 1, 0, 3, 1, 'Gd', 7, 'Typ', 1, 'Gd', 'Detchd', 1998.0, 'Unf', 3, 642, 'TA', 'TA', 'Y', 0, 35, 272, 0, 0, 0, None, None, None, 0, 2, 2006, 'WD', 'Abnorml', 140000)
# (8, 60, 'RL', None, 10382, 'Pave', None, 'IR1', 'Lvl', 'AllPub', 'Corner', 'Gtl', 'NWAmes', 'PosN', 'Norm', '1Fam', '2Story', 7, 6, 1973, 1973, 'Gable', 'CompShg', 'HdBoard', 'HdBoard', 'Stone', 240.0, 'TA', 'TA', 'CBlock', 'Gd', 'TA', 'Mn', 'ALQ', 859, 'BLQ', 32, 216, 1107, 'GasA', 'Ex', 'Y', 'SBrkr', 1107, 983, 0, 2090, 1, 0, 2, 1, 3, 1, 'TA', 7, 'Typ', 2, 'TA', 'Attchd', 1973.0, 'RFn', 2, 484, 'TA', 'TA', 'Y', 235, 204, 228, 0, 0, 0, None, None, 'Shed', 350, 11, 2009, 'WD', 'Normal', 200000)
# ...
