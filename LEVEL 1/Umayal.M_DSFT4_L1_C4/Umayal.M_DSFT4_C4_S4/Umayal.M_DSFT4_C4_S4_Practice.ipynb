# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Umayal.M_DSFT4_C4\\Umayal.M_DSFT4_C4_S4'

# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\Admin\\DS1_C4_S4_Loan_Practice.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# TASK 1
x=df[(df.Gender=='Male') & (df.Education =='Graduate') & (df.Loan_Status == 'Y')]
x
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
# TASK 2
y=df[(df.Gender== 'Female') & (df.Self_Employed== 'Yes') & (df.ApplicantIncome>4000)]
y
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %%
# TASK 3
z=df[(df.Property_Area=='Rural') & (df.Loan_Status=="Y") & (df.Dependents=="3+")]
# print(z)
print('Total no.of customers are',z.shape[0])
# or you can use len(z)
# Out:
# Total no.of customers are 13

# %%
# TASK 4
a=df[(df.LoanAmount>=290)&(df.Loan_Status=='Y')]
b=a.mean(axis = 0)
print('Average income of customers whose loan was approved is',b[0])
# Out:
# Average income of customers whose loan was approved is 18641.7
# C:\Users\Admin\AppData\Local\Temp/ipykernel_14344/3828058558.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   b=a.mean(axis = 0)

# %%
# TASK 5

# %%
c=df[(df.Married=='No') & (df.Self_Employed=="Yes") & (df.Loan_Status=='N')]
print(c)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 32   LP001097    Male      No          1      Graduate           Yes
# 95   LP001326    Male      No          0      Graduate           Yes
# 107  LP001370    Male      No          0  Not Graduate           Yes
# 199  LP001673    Male      No          0      Graduate           Yes
# 245  LP001813    Male      No          0      Graduate           Yes
# 254  LP001844    Male      No          0      Graduate           Yes
# 280  LP001910    Male      No          1  Not Graduate           Yes
# 286  LP001925  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 410  LP002318  Female      No          1  Not Graduate           Yes
# 438  LP002403    Male      No          0      Graduate           Yes
# 449  LP002444    Male      No          1  Not Graduate           Yes
# 600  LP002949  Female      No         3+      Graduate           Yes
# ...

# %%
print('Count of people genderwise falling in this category')
c["Gender"].value_counts()
# Out:
# Count of people genderwise falling in this category
# Male      9
# Female    5
# Name: Gender, dtype: int64

# %%
# TASK 6
s=df.groupby(by=['Property_Area'])['ApplicantIncome'].mean()
s
# Out:
# Property_Area
# Rural        5554.083799
# Semiurban    5292.261803
# Urban        5398.247525
# Name: ApplicantIncome, dtype: float64

# %%
# TASK 7

# %%
c7=df[(df.Loan_Status=="Y") & (df.Married=='Yes')]
a7=c7.mean(axis = 0)
c7=c7[(c7.CoapplicantIncome<a7[1])]
print('Avg of co_applicant_income is',a7[1])
print('No.of customers are',len(c7))
# Out:
# Avg of co_applicant_income is 1690.1177777383334
# No.of customers are 152
# C:\Users\Admin\AppData\Local\Temp/ipykernel_14344/973515225.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   a7=c7.mean(axis = 0)

# %%
# TASK 8
c8=df[(df.Education=='Graduate') & (df.ApplicantIncome>10256) & (df.ApplicantIncome<150000) ]
print('No.of customers are',len(c8))
# Out:
# No.of customers are 48

# %%
# TASK 9
X9=df[(df.ApplicantIncome<6000) & (df.LoanAmount>200) & (df.Loan_Status=="Y")]
X9['Gender'].value_counts()
# Out:
# Male      11
# Female     1
# Name: Gender, dtype: int64

# %%
# TASK 10
X10=df['Property_Area'].value_counts()
print(X10[0:2])
diff=X10[0]-X10[1]
print('Difference in no.of customers between Semi urban and Urban area is',diff)
print('Semiurban is',diff/X10[1]*100,'%','more than urban area')
# Out:
# Semiurban    233
# Urban        202
# Name: Property_Area, dtype: int64
# Difference in no.of customers between Semi urban and Urban area is 31
# Semiurban is 15.346534653465346 % more than urban area

# %%
# TASK 11
X11=df[df.Loan_Status=='Y']
a11=X11.sort_values(by='ApplicantIncome')
a11.tail()
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 443  LP002422   Male      No          1  Graduate            No
# 185  LP001640   Male     Yes          0  Graduate           Yes
# 155  LP001536   Male     Yes         3+  Graduate            No
# 171  LP001585   Male     Yes         3+  Graduate            No
# 333  LP002101   Male     Yes          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 443            37719                0.0         152               360
# 185            39147             4750.0         120               360
# 155            39999                0.0         600               180
# 171            51763                0.0         700               300
# 333            63337                0.0         490               180
#
#      Credit_History Property_Area Loan_Status
# 443               1     Semiurban           Y
# 185               1     Semiurban           Y
# ...

# %%
# TASK 12
X12=df[(df.Gender=='Female') & (df.Dependents=='2') & (df.Loan_Status=='Y')]
# print(X12)
Y12=X12.T
Z12=Y12[6:9:2]
Z12.T
#X12[['ApplicantIncome','LoanAmount']]
# Out:
#     ApplicantIncome LoanAmount
# 29             3750        120
# 146           14866         70
# 219            4283        127
# 468             210         98
# 516            2031        113

# %%
# TASK 13

# print(X13)
X13=df[df.LoanAmount>200]
X13.loc[(X13.Gender=='Female'),'Loan_Amount_Term']=180
df[df.LoanAmount>200]=X13
df[(df.LoanAmount>200)&(df.Gender=='Female')]
# df
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 119  LP001422  Female      No          0      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 210  LP001708  Female      No          0      Graduate            No
# 233  LP001776  Female      No          0      Graduate            No
# 255  LP001846  Female      No         3+      Graduate            No
# 493  LP002582  Female      No          0  Not Graduate           Yes
# ...

# %%
# TASK 14

# %%
df=df.rename(columns={'Loan_Amount_Term':'LoanAmountTerm'})
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 0               5849                0.0         146             360
# ...

# %%
df.loc[(df.LoanAmountTerm==12) | (df.LoanAmountTerm==36)]=60
df.loc[(df.LoanAmountTerm==12) | (df.LoanAmountTerm==36)]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, LoanAmountTerm, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
# TASK 15
c15=df[(df.Education=='Graduate') & (df.Self_Employed=='Yes') & (df.ApplicantIncome>10000)]
# c15

# %%
c15['Credit_Limit']=2*c15['ApplicantIncome']
c15[['Loan_ID','ApplicantIncome','Credit_Limit']]
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_14344/445973809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c15['Credit_Limit']=2*c15['ApplicantIncome']
#       Loan_ID  ApplicantIncome  Credit_Limit
# 54   LP001186            11500         23000
# 128  LP001451            10513         21026
# 130  LP001469            20166         40332
# 185  LP001640            39147         78294
# 199  LP001673            11000         22000
# 254  LP001844            16250         32500
# 370  LP002194            15759         31518
# 432  LP002386            12876         25752
# 438  LP002403            10416         20832
# 475  LP002527            16525         33050
# 478  LP002531            16667         33334
# ...

# %%
# TASK 16
a16=df[(df.Dependents=='3+')&(df.Education=='Not Graduate')&(df.Credit_History==0)]
a16
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 73   LP001250    Male     Yes         3+  Not Graduate            No
# 338  LP002113  Female      No         3+  Not Graduate            No
# 466  LP002500    Male     Yes         3+  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 73              4755                0.0          95             342
# 338             1830                0.0         146             360
# 466             2947             1664.0          70             180
#
#      Credit_History Property_Area Loan_Status
# 73                0     Semiurban           N
# 338               0         Urban           N
# 466               0         Urban           N

# %%
print(df.shape)
df=df.drop([73,338,466],axis=0)
print(df.shape)
# Out:
# (614, 13)
# (611, 13)

# %%
# TASK 17           
u=df[df.Education=='Graduate']['ApplicantIncome'].mean()
v=df[df.Education=='Not Graduate']['ApplicantIncome'].mean()
print('Income of Graduates=',u)
print('Income of Not Graduates=',v)
# Out:
# Income of Graduates= 5864.983263598327
# Income of Not Graduates= 3794.353846153846
