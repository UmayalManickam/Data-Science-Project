# %%
# Number={1:'Radians to degree',2:'Degree to radians',3:'Number to its factorial',4:'Number to its square root',5:'Megabyte to nibble',6:'Fraction to decimal,
#      7:'Km/hr to m/s',8:'m/s to Km/hr',9:'Int to float',10:'Float to int',11:'Decimal to octal',12:'Octal to decimal',13:'Decimal to hexadecimal',
#      14:'Hexadecimal to decimal',15:'Decimal to binary',16:'Binary to decimal',17:'Char to ASCII',18:'ASCII to char',19:'Cel to Fah',20:'Fah to cel'}


import math

def main():
    
    
    print()
    print('CHOOSE FROM THE LIST BELOW TO PERFORM CALCULATION')
    print()
    print("1:Radians to degree")
    print("2:Degree to radians")
    print("3:Number to its factorial")
    print("4:Number to its square root")
    print("5:Megabyte to nibble")
    print("6:Fraction to decimal")
    print("7:Km/hr to m/s")
    print("8:m/s to Km/hr")
    print("9:Int to float")
    print("10:Float to int")
    print("11:Decimal to octal")
    print("12:Octal to decimal")
    print("13:Decimal to hexadecimal")
    print("14:Hexadecimal to decimal")
    print("15:Decimal to binary")
    print("16:Binary to decimal")
    print("17:Char to ASCII")
    print("18:ASCII to char")
    print("19:Cel to Fah")
    print("20:Fah to cel")
    
    
    print()
    Num=int(input('Enter your choice of operation:'))
    print()
    n=input('Enter a number= ')
    
    if Num==1:
        n=float(n)
        print(r_d(n))
    elif Num==2:
        n=float(n)
        print(d_r(n))
    elif Num==3:
        n7=int(n)
        print(no_fact(n7))
    elif Num==4:
        n=int(n)
        print(no_sqrt(n))
    elif Num==5:
        n=float(n)
        print(mb_nibble(n))
    elif Num==6: 
        N1=int(input("Enter numerator="))
        N2=int(input("Enter denominator="))
        fract_dec(N1,N2)
    elif Num==7: 
        n=float(n)
        km_m(n)
    elif Num==8: 
        n=float(n)
        m_km(n)
    elif Num==9:
        int_float(n)
    elif Num==10:
        n8=float(n)
        float_int(n8)
    elif Num==11:
        n1=int(n)
        decToOct(n1)
    elif Num==12:
        OctToDec(n)
    elif Num==13:
        n3=int(n)
        decToHex(n3)
    elif Num==14:
        print(HexToDec(n))
    elif Num==15:
        n2=int(n)
        decToBin(n2)      
    elif Num==16:
        print(BinToDec(n))
    elif Num==17:
        print(c_a(n))
    elif Num==18:
        n4=int(n)
        print(a_c(n4))
    elif Num==19:
        n5=float(n)
        print(c_f(n5))
    elif Num==20:
        n6=float(n)
        print(f_c(n6))
    else:
        print('NOT APPLICABLE')
    
#1
def d_r(n):
    return (math.radians(n))
#2
def r_d(n):
    return (math.degrees(n))  
#3
def no_fact(n7):
    return(math.factorial(n7))    
#4
def no_sqrt(n):
    return (math.sqrt(n))    
#5
def mb_nibble(n):
    return (n*2097152)
#6
def fract_dec(N1,N2):
    print (N1/N2)
#7
def km_m(n):
    print(n*(5/18))
#8
def m_km(n):
    print(n*(18/5))  
#9
def int_float(n):
    print(float(n))
#10
def float_int(n8):
    print(int(n8))   
#11
def decToOct(n1):
    print(oct(n1).replace('o', '0'))
#12
def OctToDec(n):
    print(int(n,8))
#13
def decToHex(n3):
    print(hex(n3).replace('x', '0'))
# 14
def HexToDec(n):
    return int(n,16)
#15
def decToBin(n2):
    print(bin(n2).replace('b', '0'))
#16
def BinToDec(n):
    return int(n,2)  
#17
def c_a(n):
    return ord(n)
#18
def a_c(n4):
    return chr(n4)
#19
def c_f(n5):
    return ((n5*1.8)+32)
#20
def f_c(n6):
    return ((n6-32)*0.5556)


# CALLING THE MAIN FUNCTION
main()
# Out:
# CHOOSE FROM THE LIST BELOW TO PERFORM CALCULATION
#
# 1:Radians to degree
# 2:Degree to radians
# 3:Number to its factorial
# 4:Number to its square root
# 5:Megabyte to nibble
# 6:Fraction to decimal
# 7:Km/hr to m/s
# 8:m/s to Km/hr
# 9:Int to float
# 10:Float to int
# 11:Decimal to octal
# 12:Octal to decimal
# 13:Decimal to hexadecimal
# 14:Hexadecimal to decimal
# 15:Decimal to binary
# 16:Binary to decimal
# 17:Char to ASCII
# 18:ASCII to char
# 19:Cel to Fah
# 20:Fah to cel
#
# Enter your choice of operation:16
#
# Enter a number= 1011
# 11
