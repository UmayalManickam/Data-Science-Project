# %%
# answer={1:'A',2:'C',3:'A',4:'D',5:'B',6:'D',7:'B',8:'A',9:'C',10:'B',11:'A'}
# Total.No.of.Questions=11

print('MCQ QUIZ')
print()

score = 0


print('1)National Bird ?')
print('A)Peacock','B)Parrot','C)Eagle','D)Kiwi')

Q = input("Enter the correct option ")

if Q=='A' or Q=='a':
    score+= 1
else:
    print('The correct answer is: A')
    
print()
print('2)National Animal ?')
print('A)Horse','B)Elephant','C)Tiger','D)Lion')

Q = input("Enter the correct option ")

if Q=='C' or Q=='c':
    score+= 1
else:
    print('The correct answer is: C')
    

print()
print('3)National Tree ?')
print('A)Banyan','B)Neem','C)Coconut','D)Palm')

Q = input("Enter the correct option ")

if Q=='A' or Q=='a':
    score+= 1
else:
    print('The correct answer is: A')

    
    
print()
print('4)National Country ?')
print('A)China','B)Japan','C)Tibet','D)India')

Q = input("Enter the correct option ")

if Q=='D' or Q=='d':
    score+= 1
else:
    print('The correct answer is: D')
 
    
    
print()
print('5)National Language ?')
print('A)Tamil','B)Hindi','C)English','D)Kanada')

Q = input("Enter the correct option ")

if Q=='B' or Q=='b':
    score+= 1
else:
    print('The correct answer is: B')


print()
print('6)National Captial ?')
print('A)Coimbatore','B)Mumbai','C)Chennai','D)Delhi')

Q = input("Enter the correct option ")

if Q=='D' or Q=='d':
    score+= 1
else:
    print('The correct answer is: D')

    
    
print()
print('7)Manchester of India ?')
print('A)Coimbatore','B)Mumbai','C)Chennai','D)Delhi')

Q = input("Enter the correct option ")

if Q=='B' or Q=='b':
    score+= 1
else:
    print('The correct answer is: B')
    
    
    
print()
print('8)Manchester of Tamilnadu ?')
print('A)Coimbatore','B)Mumbai','C)Chennai','D)Erode')

Q = input("Enter the correct option ")

if Q=='A' or Q=='a':
    score+= 1
else:
    print('The correct answer is: A')
    
    
    
print()
print('9)Captial of Tamilnadu ?')
print('A)Coimbatore','B)Mumbai','C)Chennai','D)Delhi')

Q = input("Enter the correct option ")

if Q=='C' or Q=='c':
    score+= 1
else:
    print('The correct answer is: C')

    
print()
print('10)Republic day in India ?')
print('A)15th August','B)26th January','C)2nd October','D)14th January')

Q = input("Enter the correct option ")

if Q=='B' or Q=='b':
    score+= 1
else:
    print('The correct answer is: B')
     
    
    
print()
print('11)Independence day in India ?')
print('A)15th August','B)26th January','C)2nd October','D)14th January')

Q = input("Enter the correct option ")

if Q=='A' or Q=='a':
    score+= 1
else:
    print('The correct answer is: A')
 
    
    
    
    
    
print()    
print('TOTAL MARKS SCORED =',score,'/ 11')
print()
print()

print('The overall performance is')

if(score==11):
    print('EXCELLENT')
elif score>=8 and score<11:
    print('GOOD')
elif score<8 and score>4:
    print('AVERAGE')
else:
    print('POOR')
# Out:
# MCQ QUIZ
#
# 1)National Bird ?
# A)Peacock B)Parrot C)Eagle D)Kiwi
# Enter the correct option a
#
# 2)National Animal ?
# A)Horse B)Elephant C)Tiger D)Lion
# Enter the correct option b
# The correct answer is: C
#
# 3)National Tree ?
# A)Banyan B)Neem C)Coconut D)Palm
# Enter the correct option c
# The correct answer is: A
#
# 4)National Country ?
# A)China B)Japan C)Tibet D)India
# Enter the correct option d
#
# 5)National Language ?
# A)Tamil B)Hindi C)English D)Kanada
# Enter the correct option a
# The correct answer is: B
#
# 6)National Captial ?
# A)Coimbatore B)Mumbai C)Chennai D)Delhi
# Enter the correct option c
# The correct answer is: D
#
# 7)Manchester of India ?
# A)Coimbatore B)Mumbai C)Chennai D)Delhi
# Enter the correct option b
#
# 8)Manchester of Tamilnadu ?
# A)Coimbatore B)Mumbai C)Chennai D)Erode
# Enter the correct option a
#
# 9)Captial of Tamilnadu ?
# A)Coimbatore B)Mumbai C)Chennai D)Delhi
# Enter the correct option d
# The correct answer is: C
#
# ...
